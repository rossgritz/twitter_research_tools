# %% [markdown]
# # Clustering Analysis Notebook

# %% [markdown]
# #### This notebook contains a demonstration of the tools necessary for conducting clustering on Twitter data.

# %%
import trt_API.process as proc
import trt_API.analysis as ana
import trt_API.clustering as cluster
import trt_API.org_research as org 
import matplotlib as plt
import datetime
from sklearn.feature_extraction import text 

SORTED = False

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# ### Variables for Analysis

# %%
DIRECTORY = './tweets/*'
# Set to True to isolate english language tweets
ENGLISH = True

# %% [markdown]
# ### Load Tweet and Generate Dataframe

# %%
tweet_objects = proc.loadTweetObjects(DIRECTORY)
encoding = False
df = proc.convertTweetsToDataframe(tweet_objects, ENGLISH, encoding)
tweet_objects
print(tweet_objects)
# Out:
# Initial size: 21766
# Dropping duplicates...
# Final size: 19500
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Extract Potential Cashtags

# %%
ctdf = proc.extractPossibleCashtags(df)
ctdf
# Out:
# Total potential Cashtags: 113
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Removing Noisy Tweets

# %%
'''
*** Tweets often use popular hashtags with unrelated topics.
*** Noisy words can be identified to use to filter such tweets.
*** Enter these words below in the noisy_terms list.
'''
words = open('../resources/stop_words.csv').read().split(",")
noisy_terms = []
cldf = proc.removeNoisyTerms(df, noisy_terms)
cldf['original_tweet'][cldf.original_tweet == 'None'] = cldf['tweet']
cldf['tweet'] = cldf['original_tweet']
del cldf['original_tweet']
# Out:
# Removed 0 noisy terms.
# <ipython-input-5-87a2ef31ef5c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cldf['original_tweet'][cldf.original_tweet == 'None'] = cldf['tweet']

# %% [markdown]
# ### Remove Retweets

# %%
cldf_no_RT, cldf = proc.removeRetweets(cldf)
# Out:
# Removed 6444 duplicates.
# /Users/rajuy/Documents/twitter_research_tools-master/notebooks/trt_API/process.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RT'][df.tweet.astype(str).str[0:2] == 'RT'] = df.tweet.str.split(':',expand=True).iloc[:,0]

# %%
print(cldf_no_RT.shape[0])
# Out:
# 13056

# %% [markdown]
# ## SPLITTING DATA

# %% [markdown]
# ### By date

# %%
cldf, SORTED = ana.sortByDate(cldf,SORTED,PRINT_TOP=False,TOP=10)
begin = datetime.datetime(2017,8,1,0,00) #year, month, day, hour, minute
end = datetime.datetime(2019,2,24,23,59)
specific_range_cldf = cldf[cldf.date > begin]
specific_range_cldf = specific_range_cldf[specific_range_cldf.date < end]
# Out:
#                      date  followers       username  \
# 11381 2018-03-30 02:22:08        197   GoodIdeaAdia
# 7629  2018-03-30 02:24:23       2712    hanjangho76
# 11382 2018-03-30 02:27:20       1251       mrbertie
# 7630  2018-03-30 02:36:50         34  KhanNadir4107
# 18565 2018-03-30 02:42:25     877755          Bucks
# ...                   ...        ...            ...
# 15039 2018-05-04 01:50:05        977        anajinn
# 15040 2018-05-04 01:55:34      67640   MichaelEMann
# 391   2018-05-04 01:57:30         38  ABowlofJustin
# 11442 2018-05-04 02:04:17       4687     ComTiger86
# 392   2018-05-04 02:09:55       4722   JustTshiamo_
#
#                         location  \
# 11381                   The Town
# 7629                San Jose, CA
# 11382                       None
# 7630                        None
# 18565              Milwaukee, WI
# ...                          ...
# 15039                       None
# 15040  Penn State University, PA
# 391                    san diego
# 11442    Sydney, New South Wales
# 392              Heavenly places
#
#                                                    tweet    RT
# 11381  I'm celebrating #EarthDay by walking 20K steps...  None
# 7629   Now we lead history. #Climatechange https://t....  None
# 11382  7 ways towns and #cities are turning from grey...  None
# 7630   Blooms lovespring so much,it seems theycome,un...  None
# 18565  Game On In The Bay!!#FearTheDeer https://t.co/...  None
# ...                                                  ...   ...
# 15039  Reed Warbler. 😀Taken at RSPB Ham Wall in Somer...  None
# 15040  While some #climate contrarians suggest that c...  None
# 391    New Recap! #FearTheWalkingDead #podcast S4 E3 ...  None
# 11442  A renewable future #RenewableEnergy  #sustaina...  None
# 392    “It’s put up or shut up. It’s endurance time.”...  None
#
# [19500 rows x 6 columns]

# %% [markdown]
# ### By terms

# %%
terms_of_interest = []
print(specific_range_cldf)
# bsdf = proc.findTerms(specific_range_cldf, terms_of_interest)
# Out:
#                      date  followers       username  \
# 11381 2018-03-30 02:22:08        197   GoodIdeaAdia
# 7629  2018-03-30 02:24:23       2712    hanjangho76
# 11382 2018-03-30 02:27:20       1251       mrbertie
# 7630  2018-03-30 02:36:50         34  KhanNadir4107
# 18565 2018-03-30 02:42:25     877755          Bucks
# ...                   ...        ...            ...
# 15039 2018-05-04 01:50:05        977        anajinn
# 15040 2018-05-04 01:55:34      67640   MichaelEMann
# 391   2018-05-04 01:57:30         38  ABowlofJustin
# 11442 2018-05-04 02:04:17       4687     ComTiger86
# 392   2018-05-04 02:09:55       4722   JustTshiamo_
#
#                         location  \
# 11381                   The Town
# 7629                San Jose, CA
# 11382                       None
# 7630                        None
# 18565              Milwaukee, WI
# ...                          ...
# 15039                       None
# 15040  Penn State University, PA
# 391                    san diego
# 11442    Sydney, New South Wales
# 392              Heavenly places
#
#                                                    tweet    RT
# 11381  I'm celebrating #EarthDay by walking 20K steps...  None
# 7629   Now we lead history. #Climatechange https://t....  None
# 11382  7 ways towns and #cities are turning from grey...  None
# 7630   Blooms lovespring so much,it seems theycome,un...  None
# 18565  Game On In The Bay!!#FearTheDeer https://t.co/...  None
# ...                                                  ...   ...
# 15039  Reed Warbler. 😀Taken at RSPB Ham Wall in Somer...  None
# 15040  While some #climate contrarians suggest that c...  None
# 391    New Recap! #FearTheWalkingDead #podcast S4 E3 ...  None
# 11442  A renewable future #RenewableEnergy  #sustaina...  None
# 392    “It’s put up or shut up. It’s endurance time.”...  None
#
# [19500 rows x 6 columns]

# %% [markdown]
# ## CLUSTERING

# %%
'''
*** Enter additional stop words here.
*** This will ignore the words rather than removing tweets as with noisy Tweets.
'''
ADDITIONAL_STOP_WORDS = ['rt','wa','http','ha','1','amp']
stop_words = text.ENGLISH_STOP_WORDS.union(org.STOP_WORDS)
stop_words = stop_words.union(ADDITIONAL_STOP_WORDS)

# %%
'''
*** Clustering requires the use of a number of parameters for tuning.
*** These are included below and should be set based on your project.
'''
n_FEATURES = 300
n_TOPICS = 10
n_TOP_WORDS = 10
n_TOP_TWEETS = 10
NGRAM = 3

# %%
tfidf, tfidf_feature_names = cluster.tfidf(specific_range_cldf, n_FEATURES, \
                                           NGRAM, stop_words)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['change', 'doe', 'greeting', 'le', 'regard'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
km, kmeans_embedding = cluster.KMeans(tfidf, n_TOPICS)
# Out:
# Initialization complete
# Iteration 0, inertia 17046.257763760932
# Iteration 1, inertia 16037.900475843957
# Iteration 2, inertia 15820.721960202443
# Iteration 3, inertia 15731.23826664693
# Iteration 4, inertia 15713.545988545178
# Iteration 5, inertia 15704.902578854751
# Iteration 6, inertia 15696.325424451197
# Iteration 7, inertia 15692.97118773412
# Iteration 8, inertia 15692.523678196725
# Iteration 9, inertia 15692.07554248196
# Iteration 10, inertia 15692.034408772057
# Iteration 11, inertia 15692.009695768187
# Iteration 12, inertia 15692.004988269608
# Iteration 13, inertia 15691.994813704665
# Converged at iteration 13: strict convergence.
# KMeans(max_iter=100, n_clusters=10, n_init=1, verbose=True)

# %%
cluster.printClusterResults(specific_range_cldf, km, tfidf, tfidf_feature_names,\
                   n_TOP_WORDS, n_TOPICS, n_TOP_TWEETS)
# Out:
# Topic 1:
# celebrate
#  celebrate earthday
#  earthday
#  earth
#  earthday2018
#  april
#  planet
#  22
#  earthday18
#  day
#
# 1) @dfesta_art Celebrate #EarthDay at the gallery on April 7thhttps://t.co/o6bcORw1Az
# 2) 4 #FairTrade Chocolate Brands to Celebrate Easter Sustainably https://t.co/9pEoG5K03z #sustainability
# 3) ICYMI: We celebrate the #FantasticFour's return and Carol Danvers' 50th birthday the latest episode of #EarthsMightiestShow! Plus, Rise of the Black Panther" writer @EvNarc gets quizzed on Wakandan technology. Watch the full episode now: https://t.co/Iwu6gz8Cfe https://t.co/hhKLztUq1Y"
# 4) Cut through the hypocrisy, showcase your creative side, and maybe win $500! Enter our #EarthDayArtContest and help us celebrate the #FossilFuels that power the miracles of the modern world. #EarthDay #FossilFueled https://t.co/aUMKcJuQZy https://t.co/zTMY9xbKYI
# 5) Celebrate #EarthMonth🌎 and find an event in San Francisco motivating climate action through art, education, film and community. #SFThingToDo https://t.co/WtWHtsh7DF https://t.co/8VsCelY8rC
# 6) #Earthday is almost here. Celebrate by shopping our #Nature &amp; #Science collection of #handmade #jewelry. All sales go to @Earthjustice saving our beautiful #planet.#ClimateChange #ClimateChangeIsReal #earrings #bracelet https://t.co/7M0QihvdqN https://t.co/IL6rUhqyzp
# 7) Bring the world into your classroom via #SkypeClassroom and your @GlowScot login to celebrate #EarthDay month #DigiLearnScot #MIEExpert https://t.co/xDCkqF2dnI
# 8) It's #SignatureSunday and in salute of those no longer here post a signed memorabilia or card in your collection today to celebrate their legacy https://t.co/qZbSKXGWEr
# 10) New - Business Day: Changing How We Teach #Sustainability! #Education #Systems #Complexity #leadership Ω22 https://t.co/1dWEWm1Rpo
#
#
#
# Topic 10:
# nature
#  earthday
#  wildlife
#  love
#  photo
#  beautiful
#  naturephotography
#  mother
#  animal
#  bird
#
# 1) Blooms lovespring so much,it seems theycome,uninvited #nature#love#micropoetry
# 2) 🐋 Impressed🐋 Very Impressive🐋 Holy Sh...🐳🐋🐳🐋🐳🐋🐳#Whales #ThursdayThoughts #Ocean #Nature #ecohttps://t.co/o7z9f82yPm
# 3) #Creation_Of_Nature Who is the Creator of Nature ?Must watch 👇👇https://t.co/7VidhuCGPe... https://t.co/BWcdSeW4sB
# 4) 🌺Looks like fake! #Panama #Flowers #Nature https://t.co/Xbb0rRFFDp
# 5) Now you can live among the #clouds, https://t.co/ukKdXr6w2a Free Shipping to #USA and #Canada #Wall #Art #Nature https://t.co/40d8mHluzE
# 6) #nature Muslin Baby Blankets https://t.co/0IhA2tbdi5 https://t.co/njOS4IZTJd
# 7) The latest #Wildlife &amp; #Nature News! https://t.co/RODiluR1ov #Thanks @AgentHomeUK @SonjaYoerg @DANIELKALDERON3 #birds #nature_study
# 8) If We Don´t Take Care of Nature, Nature Will Take Care of Us: https://t.co/gBdpSbkafZ #climatechange #climateaction#environment#energy https://t.co/buY2AYM6Tq
# 9) Watch what happened at 7:02 in @PrincessNorway7's broadcast: #mountain of #Norway Skiing ⛷⛷🇳🇴 #beautiful #nature … https://t.co/gQv5q32Poy
# 10) Grand Prize, California Statewide Painting Competition https://t.co/nYhA7d2ADw #Painting #Nature

# %%
tfidf
# Out:
# <19500x300 sparse matrix of type '<class 'numpy.float64'>'
# 	with 89500 stored elements in Compressed Sparse Row format>

# %%
PERPLEXITY = 2.0
cluster.tSNE(kmeans_embedding, PERPLEXITY, n_TOPICS, title = \
              't-SNE Visualization of Data')

# %% [markdown]
# ## Compute Inertia to Determine Optimal Clusters

# %%
LOOPS = 5
n_TOPICS_START = 5
n_TOPICS_END = 25
cluster.optimalClustersKMeans(tfidf, LOOPS, n_TOPICS_START, n_TOPICS_END)

# %%
# Out:
# array([[-1.62247674, -1.95683956],
#        [-0.67852552, -1.23578271],
#        [-0.8885988 , -0.18128349],
#        [-1.0220477 , -0.51561528],
#        [-0.67709636, -0.89664679],
#        [-0.33610701, -0.88850425],
#        [-1.52973713, -0.28527934],
#        [-1.62720466, -0.60061107],
#        [-0.45931575, -1.78911657],
#        [-0.25144804, -0.71222231],
#        [-1.45635995, -1.73256919],
#        [-0.12322499, -1.7204279 ],
#        [-0.47094968, -1.08944417],
#        [-1.48203487, -1.62624791],
#        [-0.16503564, -1.31013068],
#        [-0.43190627, -1.251008  ],
#        [-0.61508202, -0.93895015],
#        [-1.36687234, -0.44530167],
#        [-0.85257223, -1.93220478],
#        [-1.0371613 , -1.76010681],
#        [-0.30541462, -1.13683291],
#        [-0.55539381, -1.39969181],
#        [-0.64514652, -1.08048392],
#        [-1.0143268 , -1.20818173],
#        [-0.30666011, -1.43260702],
#        [-0.59671435, -1.44422136],
#        [-0.86667378, -0.04378757],
#        [-1.6669031 , -0.24654434],
#        [-0.91936675, -1.05623764],
#        [-1.49627764, -1.53507941],
#        [-1.05930937, -1.93258214],
#        [-1.35857641, -0.50957097],
#        [-0.4514529 , -0.55907681],
#        [-0.27953301, -0.44300084],
#        [-1.62481149, -1.95444436],
#        [-0.78688264, -1.69164428],
#        [-0.29042072, -0.91656591],
#        [-0.60540401, -1.24457459],
#        [-0.02932568, -0.13077337],
#        [-1.65971592, -0.01513456],
#        [-1.34969878, -1.65638173],
#        [-1.98373347, -0.29224148],
#        [-0.98512023, -1.00233504],
#        [-0.32339256, -0.76370575],
#        [-0.78691352, -0.06965092],
#        [-0.78004974, -0.13235936],
#        [-0.13429243, -0.57128371],
#        [-0.04343111, -1.32459269],
#        [-0.00557926, -1.95618571],
#        [-1.2209188 , -1.1783596 ],
#        [ 2.33486079,  1.71726625],
#        [ 2.48533896,  1.36728929],
#        [ 2.32897912,  1.19967425],
#        [ 2.50509122,  2.95164717],
#        [ 1.68741417,  1.52567021],
#        [ 2.49106638,  1.20930546],
#        [ 2.45426424,  1.69411917],
#        [ 1.04585844,  2.86462213],
#        [ 1.32872963,  2.33850266],
#        [ 2.49439111,  1.87528922],
#        [ 2.55552758,  1.66714826],
#        [ 1.11227318,  2.35295835],
#        [ 2.7016154 ,  1.94949622],
#        [ 2.8736049 ,  2.08917977],
#        [ 1.15388889,  1.63980515],
#        [ 1.60507684,  2.84288881],
#        [ 1.77751032,  2.84054069],
#        [ 2.47009905,  2.87047311],
#        [ 2.86172107,  2.12071621],
#        [ 1.64105507,  2.69969247],
#        [ 2.69248265,  1.8403428 ],
#        [ 1.09072357,  2.86943476],
#        [ 2.01531901,  1.30703717],
#        [ 1.12925987,  2.85871921],
#        [ 2.29948425,  2.27272668],
#        [ 1.41056982,  2.36650342],
#        [ 1.36867363,  1.17262279],
#        [ 2.70131396,  1.28492298],
#        [ 1.80473097,  2.78000153],
#        [ 2.42325074,  1.45565113],
#        [ 1.30298142,  1.91765585],
#        [ 2.15605736,  2.47156621],
#        [ 1.75309153,  1.21966684],
#        [ 1.49463285,  1.50410081],
#        [ 1.93334461,  2.5050771 ],
#        [ 2.44514274,  2.52944779],
#        [ 1.23214523,  2.13115751],
#        [ 2.10964658,  1.68106183],
#        [ 2.27644771,  2.02010556],
#        [ 2.40621186,  2.78826981],
#        [ 1.15948293,  1.79081657],
#        [ 2.20026363,  2.69919728],
#        [ 2.70580472,  1.76831733],
#        [ 2.72597664,  1.84498716],
#        [ 1.88702144,  2.58716453],
#        [ 2.63537745,  1.87629504],
#        [ 2.53732241,  2.35817585],
#        [ 2.76966954,  1.07708224],
#        [ 2.2997399 ,  2.97236835],
#        [ 1.85407303,  1.3583081 ]])
